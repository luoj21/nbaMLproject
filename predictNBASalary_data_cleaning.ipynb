# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
# Importing datasets
# Salary data set: https://www.kaggle.com/datasets/hultm28/nba-player-salary-data-2002-2017/data
# Season data set: https://www.kaggle.com/code/koki25ando/nba-salary-prediction-using-multiple-regression/input

season_data = pd.read_csv("Seasons_Stats.csv") # Contains data of a players performance each season (pts, ast, etc)
# The latest season this goes up to is 2016-2017

salary_data = pd.read_csv("NBASalaryData03-17.csv") # Salaries of players in a given season
# The latest season this goes up to is 2017-2018

# %% [markdown]
# # Cleaning data

# %% [markdown]
# #### Season data

# %%
season_data.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
pd.unique(season_data.columns)
# Out:
# array(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS',
#        'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
#        'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS',
#        'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS'], dtype=object)

# %%
# Dropping first column
season_data.drop(columns = season_data.columns[0], inplace = True)

# %%
# Check which columns have NAs
for col in season_data.columns:
    print(col + " "  + str(season_data[col].isna().sum()))
# Out:
# Year 67
# Player 67
# Pos 67
# Age 75
# Tm 67
# G 67
# GS 6458
# MP 553
# PER 590
# TS% 153
# 3PAr 5852
# FTr 166
# ORB% 3899
# DRB% 3899
# TRB% 3120
# AST% 2136
# STL% 3899
# BLK% 3899
# TOV% 5109
# USG% 5051
# blanl 24691
# OWS 106
# DWS 106
# WS 106
# WS/48 590
# blank2 24691
# OBPM 3894
# DBPM 3894
# BPM 3894
# VORP 3894
# FG 67
# FGA 67
# FG% 166
# 3P 5764
# 3PA 5764
# 3P% 9275
# 2P 67
# 2PA 67
# 2P% 195
# eFG% 166
# FT 67
# FTA 67
# FT% 925
# ORB 3894
# DRB 3894
# TRB 379
# AST 67
# STL 3894
# BLK 3894
# TOV 5046
# PF 67
# PTS 67

# %%
season_data.isna().any()
# Out:
# Year      True
# Player    True
# Pos       True
# Age       True
# Tm        True
# G         True
# GS        True
# MP        True
# PER       True
# TS%       True
# 3PAr      True
# FTr       True
# ORB%      True
# DRB%      True
# TRB%      True
# AST%      True
# STL%      True
# BLK%      True
# TOV%      True
# USG%      True
# blanl     True
# OWS       True
# DWS       True
# WS        True
# WS/48     True
# blank2    True
# OBPM      True
# DBPM      True
# BPM       True
# VORP      True
# FG        True
# FGA       True
# FG%       True
# 3P        True
# 3PA       True
# 3P%       True
# 2P        True
# 2PA       True
# 2P%       True
# eFG%      True
# FT        True
# FTA       True
# FT%       True
# ORB       True
# DRB       True
# TRB       True
# AST       True
# STL       True
# BLK       True
# TOV       True
# PF        True
# PTS       True
# dtype: bool

# %%
# Drop rows that are all NAs
season_data.dropna(how = "all", inplace = True)

# Removing seasons prior to the 2002-2003 season
season_data = season_data[season_data.Year >= 2003]

# %%
# Making season years more descriptive
def seasonYears(year_col):
    begin = year_col - 1
    season_year = str(begin) + "-" + str(year_col)
    return(season_year)

season_data["Year"] = season_data["Year"].astype(int)
season_data["Year"] = season_data["Year"].apply(lambda x:seasonYears(x))

# Changing column names
season_data.rename(columns= {"Year": "season"}, inplace = True)
season_data.rename(columns= {"Tm": "team"}, inplace = True)

# %%
season_data.shape
# Out:
# (8671, 52)

# %%
# Printing all players
names = pd.unique(season_data.Player)
for name in names:
    print(name)
    
# Some players have * next to their name. These are HOF players, but we will need to remove the * for 
# the data cleaning
# Out:
# Tariq Abdul-Wahad
# Shareef Abdur-Rahim
# Courtney Alexander
# Malik Allen
# Ray Allen
# Rafer Alston
# John Amaechi
# Chris Andersen
# Derek Anderson
# Kenny Anderson
# Shandon Anderson
# Robert Archibald
# Gilbert Arenas
# Brandon Armstrong
# Darrell Armstrong
# Carlos Arroyo
# Chucky Atkins
# Stacey Augmon
# Dalibor Bagaric
# Vin Baker
# Brent Barry
# Jon Barry
# Maceo Baston
# Mengke Bateer
# Mike Batiste
# Tony Battie
# Shane Battier
# Lonny Baxter
# Raja Bell
# Jonathan Bender
# Corey Benjamin
# Travis Best
# Mike Bibby
# Chauncey Billups
# Corie Blount
# Mark Blount
# Calvin Booth
# Carlos Boozer
# Ruben Boumtje-Boumtje
# Bruce Bowen
# Ryan Bowen
# Earl Boykins
# Michael Bradley
# Shawn Bradley
# Elton Brand
# J.R. Bremer
# Jamison Brewer
# Primoz Brezec
# Damone Brown
# Devin Brown
# Kedrick Brown
# Kwame Brown
# P.J. Brown
# Randy Brown
# Tierre Brown
# Rick Brunson
# Kobe Bryant
# Mark Bryant
# Greg Buckner
# Pat Burke
# Caron Butler
# Rasual Butler
# Jason Caffey
# Marcus Camby
# Elden Campbell
# Brian Cardinal
# Anthony Carter
# Vince Carter
# Sam Cassell
# Kelvin Cato
# Tyson Chandler
# Calbert Cheaney
# Chris Childs
# Doug Christie
# Keon Clark
# Speedy Claxton
# Mateen Cleaves
# Derrick Coleman
# Bimbo Coles
# Jason Collier
# Jarron Collins
# Jason Collins
# Chris Crawford
# Jamal Crawford
# Austin Croshere
# John Crotty
# Eddy Curry
# Michael Curry
# Erick Dampier
# Antonio Daniels
# Antonio Davis
# Baron Davis
# Dale Davis
# Emanual Davis
# Hubert Davis
# Ricky Davis
# Andrew DeClercq
# Tony Delk
# Dan Dickau
# Michael Dickerson
# DeSagana Diop
# Vlade Divac
# Juan Dixon
# Michael Doleac
# Keyon Dooling
# Bryce Drew
# Predrag Drobnjak
# Chris Dudley
# Tim Duncan
# Mike Dunleavy
# Howard Eisley
# LaPhonso Ellis
# Melvin Ely
# Evan Eschmeyer
# Reggie Evans
# Danny Ferry
# Michael Finley
# Derek Fisher
# Marcus Fizer
# Alton Ford
# Joseph Forte
# Danny Fortson
# Greg Foster
# Jeff Foster
# Tremaine Fowlkes
# Rick Fox
# Adonal Foyle
# Steve Francis
# Lawrence Funderburke
# Dan Gadzuric
# Kevin Garnett
# Pat Garrity
# Pau Gasol
# Devean George
# Kendall Gill
# Manu Ginobili
# Gordan Giricek
# Dion Glover
# Anthony Goldwire
# Drew Gooden
# Brian Grant
# Horace Grant
# Adrian Griffin
# Eddie Griffin
# Tom Gugliotta
# A.J. Guyton
# Marcus Haislip
# Darvin Ham
# Richard Hamilton
# Zendon Hamilton
# Anfernee Hardaway
# Tim Hardaway
# Matt Harpring
# Adam Harrington
# Al Harrington
# Junior Harrington
# Othella Harrington
# Lucious Harris
# Antonio Harvey
# Donnell Harvey
# Trenton Hassell
# Kirk Haston
# Juaquin Hawkins
# Brendan Haywood
# Alan Henderson
# Nene Hilario
# Grant Hill
# Tyrone Hill
# Fred Hoiberg
# Robert Horry
# Eddie House
# Allan Houston
# Juwan Howard
# Troy Hudson
# Nate Huffman
# Larry Hughes
# Ryan Humphrey
# Lindsey Hunter
# Steven Hunter
# Zydrunas Ilgauskas
# Allen Iverson*
# Bobby Jackson
# Jermaine Jackson
# Jim Jackson
# Marc Jackson
# Mark Jackson
# Stephen Jackson
# Casey Jacobsen
# Jerome James
# Mike James
# Antawn Jamison
# Marko Jaric
# Chris Jefferies
# Richard Jefferson
# Jared Jeffries
# Anthony Johnson
# Avery Johnson
# Ervin Johnson
# Joe Johnson
# Ken Johnson
# Damon Jones
# Eddie Jones
# Fred Jones
# Jumaine Jones
# Popeye Jones
# Michael Jordan*
# Shawn Kemp
# Steve Kerr
# Jason Kidd
# Andrei Kirilenko
# Kerry Kittles
# Brevin Knight
# Travis Knight
# Toni Kukoc
# Christian Laettner
# Raef LaFrentz
# Sean Lampley
# Dan Langhi
# Voshon Lenard
# Rashard Lewis
# Randy Livingston
# Art Long
# Grant Long
# Tyronn Lue
# George Lynch
# Todd MacCulloch
# Tito Maddox
# Mark Madsen
# Corey Maggette
# Jamaal Magloire
# Karl Malone*
# Matt Maloney
# Danny Manning
# Stephon Marbury
# Shawn Marion
# Sean Marks
# Donny Marshall
# Donyell Marshall
# Kenyon Martin
# Jamal Mashburn
# Anthony Mason
# Desmond Mason
# Roger Mason
# Tony Massenburg
# Walter McCarty
# Amal McCaskill
# Jelani McCoy
# Tracy McGrady
# Jeff McInnis
# Aaron McKie
# Stanislav Medvedenko
# Ron Mercer
# Chris Mihm
# Darius Miles
# Andre Miller
# Brad Miller
# Mike Miller
# Reggie Miller*
# Chris Mills
# Yao Ming*
# Cuttino Mobley
# Nazr Mohammed
# Jerome Moiso
# Mikki Moore
# Terence Morris
# Troy Murphy
# Ronald Murray
# Tracy Murray
# Dikembe Mutombo*
# Mamadou N'Diaye
# Bostjan Nachbar
# Lee Nailon
# Eduardo Najera
# Steve Nash
# Rasho Nesterovic
# Ira Newble
# Moochie Norris
# Dirk Nowitzki
# Jermaine O'Neal
# Shaquille O'Neal*
# Charles Oakley
# Lamar Odom
# Mehmet Okur
# Dean Oliver
# Kevin Ollie
# Michael Olowokandi
# Greg Ostertag
# Bo Outlaw
# Chris Owens
# Olumide Oyedeji
# Robert Pack
# Scott Padgett
# Milt Palacio
# Jannero Pargo
# Smush Parker
# Tony Parker
# Cherokee Parks
# Ruben Patterson
# Gary Payton*
# Anthony Peeler
# Wesley Person
# Morris Peterson
# Eric Piatkowski
# Paul Pierce
# Scottie Pippen*
# Scot Pollard
# James Posey
# Lavor Postell
# Vitaly Potapenko
# Tayshaun Prince
# Joel Przybilla
# Vladimir Radmanovic
# Igor Rakocevic
# Zach Randolph
# Theo Ratliff
# Zeljko Rebraca
# Michael Redd
# Don Reid
# Efthimi Rentzias
# Glen Rice
# Jason Richardson
# Quentin Richardson
# Antoine Rigaudeau
# Clifford Robinson
# David Robinson*
# Eddie Robinson
# Glenn Robinson
# Rodney Rogers
# Sean Rooks
# Jalen Rose
# Malik Rose
# Guy Rucker
# Kareem Rush
# Bryon Russell
# Arvydas Sabonis*
# John Salmons
# Soumaila Samake
# Jamal Sampson
# Pepe Sanchez
# Jeryl Sasser
# Kenny Satterfield
# Predrag Savovic
# Brian Scalabrine
# Ansu Sesay
# Brian Shaw
# Paul Shirley
# Bobby Simmons
# Brian Skinner
# Reggie Slater
# Tamar Slay
# Charles Smith
# Joe Smith
# Steve Smith
# Eric Snow
# Latrell Sprewell
# Jerry Stackhouse
# Vladimir Stepania
# DeShawn Stevenson
# Michael Stewart
# John Stockton*
# Peja Stojakovic
# Damon Stoudamire
# Amar'e Stoudemire
# Erick Strickland
# Mark Strickland
# Rod Strickland
# Bruno Sundov
# Bob Sura
# Stromile Swift
# Wally Szczerbiak
# Maurice Taylor
# Jason Terry
# Etan Thomas
# Kenny Thomas
# Kurt Thomas
# Tim Thomas
# Jamaal Tinsley
# Oscar Torres
# Robert Traylor
# Gary Trent
# Jeff Trepagnier
# Cezary Trybanski
# Jake Tsakalidis
# Nikoloz Tskitishvili
# Hedo Turkoglu
# Nick Van
# Keith Van
# Jacque Vaughn
# Jake Voskuhl
# Dajuan Wagner
# Antoine Walker
# Samaki Walker
# Ben Wallace
# Gerald Wallace
# Rasheed Wallace
# Charlie Ward
# Earl Watson
# Clarence Weatherspoon
# Chris Webber
# Bonzi Wells
# Jiri Welsch
# David Wesley
# Jahidi White
# Rodney White
# Chris Whitney
# Chris Wilcox
# Mike Wilks
# Aaron Williams
# Alvin Williams
# Brandon Williams
# Eric Williams
# Frank Williams
# Jason Williams
# Jay Williams
# Jerome Williams
# Monty Williams
# Scott Williams
# Shammond Williams
# Walt Williams
# Corliss Williamson
# Kevin Willis
# Ruben Wolkowyski
# Loren Woods
# Qyntel Woods
# Metta World
# Lorenzen Wright
# Vincent Yarbrough
# Wang Zhizhi
# Carmelo Anthony
# Marcus Banks
# Leandro Barbosa
# Matt Barnes
# Dana Barros
# Jerome Beasley
# Troy Bell
# Steve Blake
# Keith Bogans
# Curtis Borchardt
# Chris Bosh
# Torraye Braggs
# Rodney Buford
# Mitchell Butler
# Zarko Cabarkapa
# Matt Carroll
# Maurice Carter
# Brian Cook
# Omar Cook
# Samuel Dalembert
# Marquis Daniels
# Josh Davis
# Derrick Dial
# Boris Diaw
# Kaniel Dickens
# Ronald Dupree
# Ndudi Ebi
# Francisco Elson
# Desmond Ferguson
# T.J. Ford
# Richie Frahm
# Hiram Fuller
# Reece Gaines
# Alex Garcia
# Eddie Gill
# Paul Grant
# Willie Green
# Ben Handlogten
# Travis Hansen
# Jason Hart
# Udonis Haslem
# Jarvis Hayes
# Shane Heal
# Kirk Hinrich
# Josh Howard
# Brandon Hunter
# LeBron James
# Britton Johnsen
# DerMarr Johnson
# Linton Johnson
# Dahntay Jones
# James Jones
# Chris Kaman
# Jason Kapono
# Kyle Korver
# Maciej Lampe
# Rusty LaRue
# Quincy Lewis
# Raul Lopez
# Darrick Martin
# Antonio McDyess
# Keith McLeod
# Darko Milicic
# Oliver Miller
# Alonzo Mourning*
# Lamond Murray
# Travis Outlaw
# Doug Overton
# Zaza Pachulia
# Sasha Pavlovic
# Desmond Penigar
# Kirk Penney
# Kendrick Perkins
# Mickael Pietrus
# Zoran Planinic
# Olden Polynice
# Mark Pope
# Luke Ridnour
# Michael Ruffin
# Daniel Santiago
# Jabari Smith
# Leon Smith
# Theron Smith
# Darius Songaila
# Mike Sweetney
# Ime Udoka
# Slavko Vranes
# Dwyane Wade
# John Wallace
# Luke Walton
# David West
# Mo Williams
# Cory Alexander
# Tony Allen
# Rafael Araujo
# Trevor Ariza
# Maurice Baker
# Andre Barrett
# Andris Biedrins
# Tony Bobbitt
# Matt Bonner
# Antonio Burks
# Jackie Butler
# Geno Carlisle
# Lionel Chalmers
# Josh Childress
# Nick Collison
# Erik Daniels
# Carlos Delfino
# Luol Deng
# Chris Duhon
# Corsley Edwards
# John Edwards
# Obinna Ekezie
# Andre Emmett
# Maurice Evans
# Luis Flores
# Matt Freije
# Ben Gordon
# Devin Harris
# David Harrison
# Dwight Howard
# Kris Humphries
# Andre Iguodala
# Didier Ilunga-Mbenga
# Royal Ivey
# Luke Jackson
# Al Jefferson
# Horace Jenkins
# Mark Jones
# Mario Kasun
# Viktor Khryapa
# Brandin Knight
# Nenad Krstic
# Ibo Kutluay
# Shaun Livingston
# Kevin Martin
# Anthony Miller
# Jameer Nelson
# Andres Nocioni
# Emeka Okafor
# Pavel Podkolzin
# Laron Profit
# Aleksandar Radojevic
# Peter John
# Justin Reed
# Jared Reiner
# Bernard Robinson
# Quinton Ross
# Ha Seung-Jin
# Donta Smith
# J.R. Smith
# Josh Smith
# Kirk Snyder
# Pape Sow
# Awvee Storey
# Robert Swift
# Yuta Tabuse
# Sebastian Telfair
# Billy Thomas
# James Thomas
# John Thomas
# Beno Udrih
# Anderson Varejao
# Jackson Vroman
# Sasha Vujacic
# Delonte West
# Damien Wilkins
# Dorell Wright
# Alex Acker
# Alan Anderson
# Martynas Andriuskevicius
# Earl Barron
# Eddie Basden
# Brandon Bass
# Esteban Batista
# Charlie Bell
# Andray Blatche
# Andrew Bogut
# Kevin Burleson
# Andrew Bynum
# Will Bynum
# Jose Calderon
# Travis Diener
# Ike Diogu
# Monta Ellis
# Daniel Ewing
# Noel Felix
# Raymond Felton
# Gerald Fitch
# Sharrod Ford
# Channing Frye
# Deng Gai
# Francisco Garcia
# Ryan Gomes
# Joey Graham
# Stephen Graham
# Danny Granger
# Devin Green
# Gerald Green
# Orien Greene
# Anthony Grundy
# Chuck Hayes
# Luther Head
# Julius Hodge
# Randy Holcomb
# Jarrett Jack
# Sarunas Jasikevicius
# Amir Johnson
# Dwayne Jones
# Linas Kleiza
# Yaroslav Korolev
# David Lee
# John Lucas
# Arvydas Macijauskas
# Rawle Marshall
# Jason Maxiell
# Sean May
# Rashad McCants
# Aaron Miles
# C.J. Miles
# Sergei Monia
# Boniface N'Dong
# Fabricio Oberto
# Andre Owens
# Chris Paul
# Johan Petro
# Josh Powell
# Ronnie Price
# Shavlik Randolph
# Anthony Roberson
# Lawrence Roberts
# Nate Robinson
# Melvin Sanders
# Alex Scales
# Luke Schenscher
# Wayne Simien
# James Singleton
# Salim Stoudamire
# Chris Taft
# Donell Taylor
# Dijon Thompson
# Ronny Turiaf
# Charlie Villanueva
# Von Wafer
# Matt Walsh
# Hakim Warrick
# Martell Webster
# Robert Whaley
# Deron Williams
# Lou Williams
# Marvin Williams
# Antoine Wright
# Bracey Wright
# Derrick Zimmerman
# Hassan Adams
# Maurice Ager
# LaMarcus Aldridge
# Lou Amundson
# Hilton Armstrong
# James Augustine
# Kelenna Azubuike
# Renaldo Balkman
# J.J. Barea
# Andrea Bargnani
# Will Blalock
# Josh Boone
# Cedric Bozeman
# Ronnie Brewer
# Andre Brown
# Dee Brown
# Shannon Brown
# Rodney Carney
# Mardy Collins
# Will Conroy
# Paul Davis
# Yakhouba Diawara
# Quincy Douby
# Jordan Farmar
# Desmon Farmer
# Randy Foye
# Jorge Garbajosa
# Rudy Gay
# Mickael Gelabale
# Daniel Gibson
# Andreas Glyniadakis
# Lynn Greer
# Mike Hall
# Walter Herrmann
# Robert Hite
# Ryan Hollins
# Mile Ilic
# Ersan Ilyasova
# Alexander Johnson
# Bobby Jones
# Solomon Jones
# Tarence Kinsey
# James Lang
# Kyle Lowry
# Renaldo Major
# Damir Markota
# Chris McCray
# Ivan McFarlin
# Pops Mensah-Bonsu
# Paul Millsap
# Randolph Morris
# Adam Morrison
# David Noel
# Steve Novak
# Patrick O'Bryant
# Anthony Parker
# Kevinn Pinkney
# Leon Powe
# Roger Powell
# Chris Quinn
# Allan Ray
# J.J. Redick
# Jeremy Richardson
# Sergio Rodriguez
# Rajon Rondo
# Brandon Roy
# Thabo Sefolosha
# Mouhamed Sene
# Cedric Simmons
# Uros Slokar
# Craig Smith
# Steven Smith
# Vassilis Spanoulis
# Tyrus Thomas
# P.J. Tucker
# Marcus Vinicius
# James White
# Justin Williams
# Marcus Williams
# Shawne Williams
# Shelden Williams
# Arron Afflalo
# Blake Ahearn
# Lance Allred
# Morris Almond
# Joel Anthony
# Marco Belinelli
# Corey Brewer
# Aaron Brooks
# Wilson Chandler
# Mike Conley
# Daequan Cook
# Javaris Crittenton
# Jermareo Davidson
# Glen Davis
# Guillermo Diaz
# Jared Dudley
# Kevin Durant
# Nick Fazekas
# Kyrylo Fesenko
# Thomas Gardner
# Marcin Gortat
# Aaron Gray
# Jeff Green
# Taurean Green
# Mike Harris
# Spencer Hawes
# Al Horford
# Yi Jianlian
# Coby Karl
# Carl Landry
# Keith Langford
# Stephane Lasme
# Acie Law
# Ian Mahinmi
# Dominic McGuire
# Josh McRoberts
# Jamario Moon
# Juan Carlos
# Demetris Nichols
# Joakim Noah
# Oleksiy Pecherov
# Kosta Perovic
# Kasib Powell
# Gabe Pruitt
# Chris Richard
# Cheikh Samb
# Luis Scola
# Ramon Sessions
# Courtney Sims
# Jason Smith
# D.J. Strawberry
# Rodney Stuckey
# Al Thornton
# Alando Tucker
# Darius Washington
# Darryl Watkins
# C.J. Watson
# Mario West
# Sean Williams
# Brandan Wright
# Julian Wright
# Nick Young
# Thaddeus Young
# Alexis Ajinca
# Joe Alexander
# Ryan Anderson
# Darrell Arthur
# D.J. Augustin
# Nicolas Batum
# Jerryd Bayless
# Michael Beasley
# Bobby Brown
# Mario Chalmers
# Joe Crawford
# Joey Dorsey
# Chris Douglas-Roberts
# Goran Dragic
# Rudy Fernandez
# Danilo Gallinari
# Marc Gasol
# J.R. Giddens
# Eric Gordon
# Donte Greene
# Hamed Haddadi
# Malik Hairston
# Roy Hibbert
# J.J. Hickson
# George Hill
# Steven Hill
# Othello Hunter
# Darnell Jackson
# Nathan Jawai
# Dontell Jefferson
# Trey Johnson
# DeAndre Jordan
# Kosta Koufos
# Rob Kurz
# Courtney Lee
# Brook Lopez
# Robin Lopez
# Kevin Love
# Cartier Martin
# O.J. Mayo
# Luc Mbah
# JaVale McGee
# Anthony Morrow
# DeMarcus Nelson
# Greg Oden
# Anthony Randolph
# Derrick Rose
# Brandon Rush
# Walter Sharpe
# Sean Singletary
# Will Solomon
# Marreese Speights
# Mike Taylor
# Jason Thompson
# Anthony Tolliver
# Roko Ukic
# Henry Walker
# Kyle Weaver
# Sonny Weems
# Russell Westbrook
# D.J. White
# Jawad Williams
# Sun Yue
# David Andersen
# Antonio Anderson
# Jeff Ayres
# Rodrigue Beaubois
# DeJuan Blair
# Jon Brockman
# Derrick Brown
# Chase Budinger
# DeMarre Carroll
# Omri Casspi
# Earl Clark
# Darren Collison
# Dante Cunningham
# JamesOn Curry
# Stephen Curry
# Austin Daye
# DeMar DeRozan
# Toney Douglas
# Wayne Ellington
# Tyreke Evans
# Jonny Flynn
# Sundiata Gaines
# Alonzo Gee
# Taj Gibson
# Trey Gilder
# Danny Green
# Taylor Griffin
# Tyler Hansbrough
# James Harden
# Gerald Henderson
# Jordan Hill
# Jrue Holiday
# Lester Hudson
# Chris Hunter
# Serge Ibaka
# Cedric Jackson
# Othyus Jeffers
# Brandon Jennings
# Jonas Jerebko
# James Johnson
# Oliver Lafayette
# Marcus Landry
# Ty Lawson
# Wesley Matthews
# Eric Maynor
# Jodie Meeks
# Patty Mills
# Byron Mullens
# A.J. Price
# DaJuan Summers
# Jermaine Taylor
# Jeff Teague
# Garrett Temple
# Hasheem Thabeet
# Marcus Thornton
# Reggie Williams
# Terrence Williams
# Sam Young
# Jeff Adrien
# Solomon Alabi
# Cole Aldrich
# Al-Farouq Aminu
# James Anderson
# Omer Asik
# Luke Babbitt
# Eric Bledsoe
# Trevor Booker
# Craig Brackins
# Avery Bradley
# Derrick Caracter
# Sherron Collins
# Marcus Cousin
# DeMarcus Cousins
# Jordan Crawford
# Ed Davis
# Zabian Dowdell
# Devin Ebanks
# Semih Erden
# Jeremy Evans
# Patrick Ewing
# Christian Eyenga
# Derrick Favors
# Landry Fields
# Gary Forbes
# Paul George
# Blake Griffin
# Luke Harangody
# Manny Harris
# Gordon Hayward
# Lazar Hayward
# Xavier Henry
# Damion James
# Eugene Jeter
# Armon Johnson
# Chris Johnson
# Wesley Johnson
# Dominique Jones
# Gani Lawal
# Jeremy Lin
# Greg Monroe
# Timofey Mozgov
# Hamady N'Diaye
# Gary Neal
# Larry Owens
# Patrick Patterson
# Nikola Pekovic
# Dexter Pittman
# Quincy Pondexter
# Andy Rautins
# Samardo Samuels
# Larry Sanders
# Kevin Seraphin
# Mustafa Shakur
# Garret Siler
# Ish Smith
# Tiago Splitter
# Lance Stephenson
# Pape Sy
# Evan Turner
# Ekpe Udoh
# Ben Uzoh
# Greivis Vasquez
# John Wall
# Willie Warren
# Hassan Whiteside
# Lavoy Allen
# Gustavo Ayon
# Keith Benson
# Bismack Biyombo
# MarShon Brooks
# Alec Burks
# Jimmy Butler
# Derrick Byars
# Norris Cole
# Eric Dawson
# Justin Dentmon
# Jerome Dyson
# Kenneth Faried
# Jeff Foote
# Courtney Fortson
# Jimmer Fredette
# Mickell Gladness
# Andrew Goudelock
# Jordan Hamilton
# Justin Harper
# Josh Harrellson
# Terrel Harris
# Tobias Harris
# Cory Higgins
# Darington Hobson
# Tyler Honeycutt
# Dennis Horner
# Kyrie Irving
# Reggie Jackson
# Charles Jenkins
# Carldell Johnson
# Ivan Johnson
# JaJuan Johnson
# Jerome Jordan
# Cory Joseph
# Enes Kanter
# D.J. Kennedy
# Brandon Knight
# Malcolm Lee
# Kawhi Leonard
# Travis Leslie
# Jon Leuer
# DeAndre Liggins
# Shelvin Mack
# Vernon Macklin
# E'Twaun Moore
# Darius Morris
# Marcus Morris
# Markieff Morris
# Daniel Orton
# Jeremy Pargo
# Chandler Parsons
# Ryan Reid
# Ricky Rubio
# Walker Russell
# Josh Selby
# Iman Shumpert
# Xavier Silas
# Chris Singleton
# Donald Sloan
# Greg Smith
# Jerry Smith
# Nolan Smith
# Greg Stiemsma
# Julyan Stone
# Isaiah Thomas
# Lance Thomas
# Malcolm Thomas
# Trey Thompkins
# Klay Thompson
# Mychel Thompson
# Tristan Thompson
# Jeremy Tyler
# Edwin Ubiles
# Jan Vesely
# Nikola Vucevic
# Kemba Walker
# Derrick Williams
# Elliot Williams
# Jordan Williams
# Chris Wright
# Quincy Acy
# Josh Akognon
# Harrison Barnes
# Will Barton
# Aron Baynes
# Kent Bazemore
# Bradley Beal
# Patrick Beverley
# Victor Claver
# Chris Copeland
# Jae Crowder
# Jared Cunningham
# Anthony Davis
# Nando De
# Andre Drummond
# Kim English
# Festus Ezeli
# Evan Fournier
# Joel Freeland
# Diante Garrett
# Draymond Green
# Ben Hansbrough
# Maurice Harkless
# John Henson
# Justin Holiday
# Bernard James
# John Jenkins
# Orlando Johnson
# Darius Johnson-Odom
# DeQuan Jones
# Kevin Jones
# Perry Jones
# Terrence Jones
# Kris Joseph
# Michael Kidd-Gilchrist
# Viacheslav Kravtsov
# Doron Lamb
# Jeremy Lamb
# Meyers Leonard
# Damian Lillard
# Scott Machado
# Kendall Marshall
# Fab Melo
# Khris Middleton
# Darius Miller
# Quincy Miller
# Donatas Motiejunas
# Arnett Moultrie
# Kevin Murphy
# Andrew Nicholson
# Kyle O'Quinn
# Tim Ohlbrecht
# Miles Plumlee
# Pablo Prigioni
# Austin Rivers
# Brian Roberts
# Thomas Robinson
# Terrence Ross
# Robert Sacre
# Mike Scott
# Tornike Shengelia
# Alexey Shved
# Henry Sims
# Kyle Singler
# Jared Sullinger
# Jeffery Taylor
# Tyshawn Taylor
# Marquis Teague
# Mirza Teletovic
# Jonas Valanciunas
# Jarvis Varnado
# Dion Waiters
# Maalik Wayns
# Tony Wroten
# Luke Zeller
# Tyler Zeller
# Steven Adams
# Giannis Antetokounmpo
# Pero Antic
# Chris Babb
# Anthony Bennett
# Vander Blue
# Lorenzo Brown
# Reggie Bullock
# Trey Burke
# Dwight Buycks
# Nick Calathes
# Kentavious Caldwell-Pope
# Isaiah Canaan
# Michael Carter-Williams
# Dionte Christmas
# Ian Clark
# Robert Covington
# Allen Crabbe
# Seth Curry
# Troy Daniels
# Luigi Datome
# Brandon Davies
# Dewayne Dedmon
# Matthew Dellavedova
# Gorgui Dieng
# Shane Edwards
# Vitor Faverani
# Carrick Felix
# Jamaal Franklin
# Rudy Gobert
# Archie Goodwin
# Jorge Gutierrez
# Justin Hamilton
# Elias Harris
# Solomon Hill
# Scotty Hopson
# Robbie Hummel
# Sergey Karasev
# Ryan Kelly
# Ognjen Kuzmic
# Shane Larkin
# Ricky Ledo
# Alex Len
# Ray McCallum
# C.J. McCollum
# Ben McLemore
# Gal Mekel
# Tony Mitchell
# Shabazz Muhammad
# Erik Murphy
# Toure' Murry
# Mike Muscala
# Nemanja Nedovic
# James Nunnally
# Victor Oladipo
# Kelly Olynyk
# Arinze Onuaku
# Mason Plumlee
# Otto Porter
# Phil Pressey
# Miroslav Raduljica
# Andre Roberson
# Dennis Schroder
# Peyton Siva
# Chris Smith
# Tony Snell
# James Southerland
# D.J. Stephens
# Adonis Thomas
# Hollis Thompson
# Casper Ware
# Royce White
# Jeff Withey
# Nate Wolters
# Cody Zeller
# Jordan Adams
# Furkan Aldemir
# Kyle Anderson
# Cameron Bairstow
# Jerrelle Benimon
# Sim Bhullar
# Tarik Black
# Bojan Bogdanovic
# Jabari Brown
# Markel Brown
# Bruno Caboclo
# Clint Capela
# Will Cherry
# Patrick Christopher
# Jordan Clarkson
# Jack Cooley
# Bryce Cotton
# Andre Dawkins
# Spencer Dinwiddie
# Zoran Dragic
# Larry Drew
# Cleanthony Early
# James Ennis
# Tyler Ennis
# Dante Exum
# Tim Frazier
# Langston Galloway
# Aaron Gordon
# Drew Gordon
# Jerami Grant
# Erick Green
# JaMychal Green
# P.J. Hairston
# Gary Harris
# Joe Harris
# Rodney Hood
# Joe Ingles
# Cory Jefferson
# Grant Jerrett
# Nick Johnson
# Tyler Johnson
# Sean Kilpatrick
# Alex Kirk
# Joffrey Lauvergne
# Zach LaVine
# Kalin Lucas
# Devyn Marble
# James Michael
# K.J. McDaniels
# Doug McDermott
# Mitch McGary
# Jerel McNeal
# Elijah Millsap
# Nikola Mirotic
# Eric Moreland
# Shabazz Napier
# Nerlens Noel
# Lucas Nogueira
# Jusuf Nurkic
# Johnny O'Bryant
# Kostas Papanikolaou
# Jabari Parker
# Adreian Payne
# Elfrid Payton
# Dwight Powell
# Julius Randle
# Damjan Rudez
# JaKarr Sampson
# Marcus Smart
# Russ Smith
# Nik Stauskas
# David Stockton
# Jarnell Stokes
# Noah Vonleh
# T.J. Warren
# David Wear
# Travis Wear
# Shayne Whittington
# Andrew Wiggins
# C.J. Wilcox
# James Young
# Cliff Alexander
# Justin Anderson
# Thanasis Antetokounmpo
# Keith Appling
# Nemanja Bjelica
# Devin Booker
# Anthony Brown
# Willie Cauley-Stein
# Rakeem Christmas
# Coty Clarke
# Pat Connaughton
# Branden Dawson
# Bryce Dejean-Jones
# Sam Dekker
# Duje Dukan
# Jarell Eddie
# Cristiano Felicio
# Jerian Grant
# Montrezl Harrell
# Aaron Harrison
# Mario Hezonja
# Darrun Hilliard
# Rondae Hollis-Jefferson
# Richaun Holmes
# Marcelo Huertas
# Josh Huestis
# R.J. Hunter
# Damien Inglis
# Stanley Johnson
# Nikola Jokic
# Tyus Jones
# Frank Kaminsky
# Sasha Kaun
# Kevon Looney
# Trey Lyles
# Boban Marjanovic
# Jarell Martin
# T.J. McConnell
# Chris McCullough
# Jordan McRae
# Salah Mejri
# Jordan Mickey
# Luis Montero
# Emmanuel Mudiay
# Xavier Munford
# Larry Nance
# Raul Neto
# J.J. O'Brien
# Jahlil Okafor
# Kelly Oubre
# Lamar Patterson
# Cameron Payne
# Tibor Pleiss
# Bobby Portis
# Kristaps Porzingis
# Norman Powell
# Willie Reed
# Josh Richardson
# Terry Rozier
# D'Angelo Russell
# Jonathon Simmons
# Alex Stepheson
# Walter Tavares
# Axel Toupane
# Karl-Anthony Towns
# Myles Turner
# Rashad Vaughn
# Briante Weber
# Alan Williams
# Justise Winslow
# Christian Wood
# Delon Wright
# Joe Young
# Alex Abrines
# Ron Baker
# Wade Baldwin
# Malik Beasley
# DeAndre' Bembry
# Dragan Bender
# Ben Bentil
# Davis Bertans
# Joel Bolomboy
# Malcolm Brogdon
# Jaylen Brown
# Nicolas Brussino
# Marquese Chriss
# Semaj Christon
# Quinn Cook
# Deyonta Davis
# Malcolm Delaney
# Cheick Diallo
# Kris Dunn
# Henry Ellenson
# Joel Embiid
# Kay Felder
# Yogi Ferrell
# Dorian Finney-Smith
# Bryn Forbes
# Patricio Garino
# Michael Gbinije
# Marcus Georges-Hunt
# Jonathan Gibson
# Treveon Graham
# A.J. Hammons
# Andrew Harrison
# Juan Hernangomez
# Willy Hernangomez
# Buddy Hield
# Danuel House
# Brandon Ingram
# Demetrius Jackson
# Pierre Jackson
# Brice Johnson
# Damian Jones
# Derrick Jones
# Mindaugas Kuzminskas
# Skal Labissiere
# Nicolas Laprovittola
# Jake Layman
# Caris LeVert
# Shawn Long
# Timothe Luwawu-Cabarrot
# Thon Maker
# Patrick McCaw
# Sheldon McClellan
# Rodney McGruder
# Dejounte Murray
# Jamal Murray
# Maurice Ndour
# Georges Niang
# David Nwaba
# Daniel Ochefu
# Chinanu Onuaku
# Georgios Papagiannis
# Gary Payton
# Marshall Plumlee
# Jakob Poeltl
# Alex Poythress
# Tim Quarterman
# Chasson Randle
# Malachi Richardson
# Domantas Sabonis
# Dario Saric
# Tomas Satoransky
# Wayne Selden
# Pascal Siakam
# Diamond Stone
# Edy Tavares
# Isaiah Taylor
# Mike Tobey
# Tyler Ulis
# Jarrod Uthoff
# Denzel Valentine
# Fred VanVleet
# Taurean Waller-Prince
# Okaro White
# Isaiah Whitehead
# Troy Williams
# Kyle Wiltjer
# Stephen Zimmerman
# Paul Zipser
# Ivica Zubac

# %%
season_data["Player"] = season_data["Player"].str.replace("\*", "", regex = True)

# %% [markdown]
# One of the biggest challenges with this data pre-processing is addressing the issue when a player is traded during the season. When this occurs, that player will have two or more rows showing their statistics for each team that they played for. However, the machine learning models in this case will interpret these rows as being multiple players, when in fact they only represent one player. This can lead to issues in the training/test data as the data may be skewed if a player performs drastically different on one team than on another. This is addressed by "combining" the rows of each player that played on multiple teams in one season.

# %%
dup_df = season_data[season_data.duplicated(subset = ["season", "Player"], keep = False)]
# keep = False here is essential as it marks ALL duplicates as True, not limiting 
# it up till the first or last occurence

non_dup_df = season_data[~season_data.duplicated(subset = ["season", "Player"], keep = False)]

# %%
agg_functions = {"season": "first", "PTS": "sum", "AST": "sum", "BLK": "sum", "TOV": "sum", 
                "STL": "sum", "ORB": "sum", "DRB": "sum", "MP": "sum", "G": "sum", "GS": "sum", "TOV": "sum",
                "PF": "sum", "Pos": "first", "Age": "first", "FTA": "sum", "FGA": "sum", "3PA": "sum",
                "PER": "mean", "WS": "sum"}  
# Most of these are sums, ie total number of games, points, etc that a player has accumulated during their time with
# multiple teams in a particular season. 

dup_df = dup_df.groupby("Player").aggregate(agg_functions).reset_index()
dup_df["team"] = "TOT"

#dup_df[dup_df.duplicated(["Player", "season"])]

# %%
dup_df = dup_df[['season', 'Player', 'Pos', 'Age', 'team', 'PTS', 'AST', 'BLK', 'TOV', 'STL', 'ORB',
       'DRB', 'MP', 'G', 'GS', 'PF', 'FTA', 'FGA', '3PA',
       'PER', 'WS']]
dup_df.head()
# Out:
#       season          Player Pos   Age team     PTS     AST   BLK    TOV  \
# 0  2014-2015      A.J. Price  PG  28.0  TOT   266.0    92.0   0.0   28.0
# 1  2010-2011    Aaron Brooks  PG  26.0  TOT  3310.0  1160.0  52.0  566.0
# 2  2009-2010      Aaron Gray   C  25.0  TOT   338.0    88.0  38.0   98.0
# 3  2004-2005  Aaron Williams   C  33.0  TOT   590.0    50.0  58.0   94.0
# 4  2009-2010        Acie Law  PG  25.0  TOT   656.0   220.0   2.0  120.0
#
#      STL  ...    DRB      MP      G    GS     PF    FTA     FGA     3PA  \
# 0   14.0  ...   52.0   648.0   52.0   0.0   30.0   48.0   274.0   114.0
# 1  232.0  ...  444.0  7676.0  368.0  88.0  710.0  574.0  2968.0  1236.0
# 2   38.0  ...  260.0  1332.0  138.0  12.0  236.0   96.0   286.0     2.0
# 3   44.0  ...  320.0  2212.0  180.0  18.0  416.0  150.0   478.0     0.0
# 4   86.0  ...  130.0  1920.0  154.0   2.0  154.0  226.0   522.0   104.0
#
#          PER   WS
# 0   8.800000  0.6
# 1  11.911111  8.2
# 2  10.566667  2.0
# 3   8.183333  3.7
# 4  11.685714  2.0
#
# [5 rows x 21 columns]

# %%
non_dup_df = non_dup_df[['season', 'Player', 'Pos', 'Age', 'team', 'PTS', 'AST', 'BLK', 'TOV', 'STL', 'ORB',
       'DRB', 'MP', 'G', 'GS', 'PF', 'FTA', 'FGA', '3PA', '3P', 'FG', 'FT',
       'PER', 'WS']]

non_dup_df.head()
# Out:
#           season               Player Pos   Age team     PTS    AST   BLK  \
# 16006  2002-2003    Tariq Abdul-Wahad  SG  28.0  DAL    57.0   21.0   3.0
# 16007  2002-2003  Shareef Abdur-Rahim  PF  26.0  ATL  1608.0  242.0  38.0
# 16008  2002-2003   Courtney Alexander  PG  25.0  NOH   523.0   79.0   6.0
# 16009  2002-2003          Malik Allen  PF  24.0  MIA   767.0   54.0  78.0
# 16013  2002-2003         Rafer Alston  PG  26.0  TOR   366.0  192.0  15.0
#
#          TOV   STL  ...    GS     PF    FTA     FGA    3PA    3P     FG  \
# 16006    7.0   6.0  ...   0.0   26.0    6.0    58.0    1.0   0.0   27.0
# 16007  212.0  87.0  ...  81.0  240.0  541.0  1183.0   60.0  21.0  566.0
# 16008   68.0  31.0  ...   7.0  125.0  146.0   505.0   57.0  19.0  193.0
# 16009  128.0  37.0  ...  73.0  234.0  121.0   790.0    4.0   0.0  335.0
# 16013   86.0  38.0  ...   4.0  120.0   54.0   335.0  130.0  51.0  139.0
#
#           FT   PER   WS
# 16006    3.0  12.4  0.4
# 16007  455.0  19.9  9.7
# 16008  118.0   9.3  1.1
# 16009   97.0   9.9  0.9
# 16013   37.0  14.4  1.2
#
# [5 rows x 24 columns]

# %%
season_data_new = pd.concat([non_dup_df, dup_df])

# %%
# Getting average game statistics for each player (ie points per game, rebounds per game, etc)
season_data_new["ppg"] = season_data_new["PTS"] / season_data_new["G"]
season_data_new["ast_pg"] = season_data_new["AST"] / season_data_new["G"]
season_data_new["blk_pg"] = season_data_new["BLK"] / season_data_new["G"]
season_data_new["tov_pg"] = season_data_new["TOV"] / season_data_new["G"]
season_data_new["stl_pg"] = season_data_new["STL"] / season_data_new["G"]
season_data_new["reb_pg"] = (season_data_new["ORB"] + season_data_new["DRB"]) / season_data_new["G"]
season_data_new["min_pg"] = season_data_new["MP"] / season_data_new["G"]
season_data_new["FG%"] = season_data_new["FG"] / season_data_new["FGA"]
season_data_new["FT%"] = season_data_new["FT"] / season_data_new["FTA"]
season_data_new["3P%"] = season_data_new["3P"] / season_data_new["3PA"]

# %%
season_data_new = season_data_new.sort_values("season")
season_data_new.reset_index(drop = True)
season_data_new.head()

#season_data_new[season_data_new.duplicated(["Player", "season"])]
# Out:
#           season               Player Pos   Age team    PTS   AST   BLK  \
# 16006  2002-2003    Tariq Abdul-Wahad  SG  28.0  DAL   57.0  21.0   3.0
# 16364  2002-2003        Zach Randolph  PF  21.0  POR  650.0  41.0  14.0
# 16363  2002-2003       Igor Rakocevic  PG  24.0  MIN   78.0  33.0   0.0
# 16362  2002-2003  Vladimir Radmanovic  PF  22.0  SEA  724.0  97.0  22.0
# 16361  2002-2003       Joel Przybilla   C  23.0  MIL   48.0  12.0  45.0
#
#          TOV   STL  ...        ppg    ast_pg    blk_pg    tov_pg    stl_pg  \
# 16006    7.0   6.0  ...   4.071429  1.500000  0.214286  0.500000  0.428571
# 16364   62.0  42.0  ...   8.441558  0.532468  0.181818  0.805195  0.545455
# 16363   23.0   4.0  ...   1.857143  0.785714  0.000000  0.547619  0.095238
# 16362  100.0  64.0  ...  10.055556  1.347222  0.305556  1.388889  0.888889
# 16361   19.0  10.0  ...   1.500000  0.375000  1.406250  0.593750  0.312500
#
#          reb_pg     min_pg       FG%       FT%       3P%
# 16006  2.857143  14.571429  0.465517  0.500000  0.000000
# 16364  4.454545  16.896104  0.512621  0.757764  0.000000
# 16363  0.404762   5.809524  0.379310  0.805556  0.416667
# 16362  4.486111  26.527778  0.410180  0.705882  0.354949
# 16361  4.531250  17.062500  0.391304  0.500000       NaN
#
# [5 rows x 34 columns]

# %%
season_data_new.shape
# note that the dimensions are smaller from season_data
# Out:
# (6668, 34)

# %%
season_data_new.to_csv("Season_Stats_New.csv")

# %% [markdown]
# #### Salary Data

# %%
salary_data.head()
# Out:
#                      team      salary            player position     season
# 0  Minnesota Timberwolves  25200000.0     Kevin Garnett       PF  2002-2003
# 1  Portland Trail Blazers  13500000.0  Damon Stoudamire       PG  2002-2003
# 2     Seattle SuperSonics  13080000.0       Gary Payton       PG  2002-2003
# 3     Seattle SuperSonics  12375000.0         Ray Allen       SG  2002-2003
# 4         New York Knicks  12375000.0  Latrell Sprewell       SG  2002-2003

# %%
# Renaming columns
salary_data.rename(columns = {"player": "Player"}, inplace = True)

# Scaling salary to millions
salary_data["salary"] = salary_data["salary"] / 1000000

# %%
dup_df_s = salary_data[salary_data.duplicated(subset = ["season", "Player"], keep = False)]
dup_df_s.head()
# Out:
#                         team    salary           Player position     season
# 1666         New Jersey Nets  1.180200  Marcus Williams       PG  2007-2008
# 1772       San Antonio Spurs  0.050254  Marcus Williams       SG  2007-2008
# 4020   Oklahoma City Thunder  0.473604     Chris Wright       SF  2012-2013
# 4031  Minnesota Timberwolves  0.346781    Chris Johnson        C  2012-2013
# 4065       Memphis Grizzlies  0.055718    Chris Johnson       SG  2012-2013

# %%
non_dup_df_s = salary_data[~salary_data.duplicated(subset = ["season", "Player"], keep = False)]
non_dup_df_s.head()
# Out:
#                      team  salary            Player position     season
# 0  Minnesota Timberwolves  25.200     Kevin Garnett       PF  2002-2003
# 1  Portland Trail Blazers  13.500  Damon Stoudamire       PG  2002-2003
# 2     Seattle SuperSonics  13.080       Gary Payton       PG  2002-2003
# 3     Seattle SuperSonics  12.375         Ray Allen       SG  2002-2003
# 4         New York Knicks  12.375  Latrell Sprewell       SG  2002-2003

# %%
agg_functions = {"season": "first", "position": "first", "salary": "mean"}
dup_df_s = dup_df_s.groupby("Player").aggregate(agg_functions).reset_index()
dup_df_s["team"] = 'Two or more teams'

# %%
dup_df_s = dup_df_s[["team", "salary", "Player", "position", "season"]]
dup_df_s.head()
# Out:
#                 team    salary           Player position     season
# 0  Two or more teams  0.201249    Chris Johnson        C  2012-2013
# 1  Two or more teams  0.250731     Chris Wright       SF  2012-2013
# 2  Two or more teams  0.615227  Marcus Williams       PG  2007-2008

# %%
salary_data_new = pd.concat([non_dup_df_s, dup_df_s])
#salary_data_new[salary_data_new.duplicated(["Player", "season"])]

salary_data_new.to_csv("NBASalaryData03-17_New.csv")

# %% [markdown]
# #### Joined Data

# %%
print(pd.unique(season_data_new.team))
# Note TOT means a player played for 2 or more teams in a season

print(pd.unique(salary_data_new.team))
# Out:
# ['DAL' 'POR' 'MIN' 'SEA' 'MIL' 'DET' 'NYK' 'SAC' 'BOS' 'ATL' 'LAC' 'MEM'
#  'SAS' 'CLE' 'LAL' 'UTA' 'NOH' 'TOR' 'NJN' 'DEN' 'ORL' 'PHI' 'WAS' 'GSW'
#  'CHI' 'HOU' 'PHO' 'IND' 'MIA' 'TOT' 'CHA' 'NOK' 'OKC' 'BRK' 'NOP' 'CHO']
# ['Minnesota Timberwolves' 'Portland Trail Blazers' 'Seattle SuperSonics'
#  'New York Knicks' 'Boston Celtics' 'Phoenix Suns' 'San Antonio Spurs'
#  'Orlando Magic' 'Indiana Pacers' 'Los Angeles Lakers' 'Toronto Raptors'
#  'Dallas Mavericks' 'Sacramento Kings' 'Miami Heat' 'Milwaukee Bucks'
#  'Atlanta Hawks' 'Philadelphia 76ers' 'New Jersey Nets' 'Houston Rockets'
#  'Utah Jazz' 'Denver Nuggets' 'Detroit Pistons' 'New Orleans Hornets'
#  'Chicago Bulls' 'Memphis Grizzlies' 'Golden State Warriors' 'LA Clippers'
#  'Washington Wizards' 'Cleveland Cavaliers' 'Charlotte Bobcats'
#  'NO/Oklahoma City\r\r\n Hornets' 'Brooklyn Nets'
#  'NO/Oklahoma City Hornets' 'Oklahoma City Thunder' 'Madrid Real Madrid'
#  'null Unknown' 'New Orleans Pelicans' 'Charlotte Hornets' 'Milan Olimpia'
#  'Bilbao Basket Bilbao Basket' 'Fenerbahce Ulker Fenerbahce Ulker'
#  'Perth Perth' 'Flamengo Flamengo' 'Melbourne United' 'Shanghai Sharks'
#  'Beijing Ducks' 'Two or more teams']

# %%
# Abbreviating NBA team names
def teamName(tm_col):
    nba_teams = {
    'Atlanta Hawks': 'ATL',
    'Boston Celtics': 'BOS',
    'Brooklyn Nets': 'BRK',
    'Charlotte Bobcats': 'CHA',
    'Charlotte Hornets': 'CHO',
    'Chicago Bulls': 'CHI',
    'Cleveland Cavaliers': 'CLE',
    'Dallas Mavericks': 'DAL',
    'Denver Nuggets': 'DEN',
    'Detroit Pistons': 'DET',
    'Golden State Warriors': 'GSW',
    'Houston Rockets': 'HOU',
    'Indiana Pacers': 'IND',
    'LA Clippers': 'LAC',
    'Los Angeles Lakers': 'LAL',
    'Memphis Grizzlies': 'MEM',
    'Miami Heat': 'MIA',
    'Milwaukee Bucks': 'MIL',
    'Minnesota Timberwolves': 'MIN',
    'New Orleans Pelicans': 'NOP',
    'New Orleans Hornets': 'NOH',
    'New York Knicks': 'NYK',
    'New Orleans/Oklahoma City Hornets': 'NOK',
    'New Jersey Nets': 'NJN',
    'Oklahoma City Thunder': 'OKC',
    'Orlando Magic': 'ORL',
    'Philadelphia 76ers': 'PHI',
    'Phoenix Suns': 'PHO',
    'Portland Trail Blazers': 'POR',
    'Sacramento Kings': 'SAC',
    'San Antonio Spurs': 'SAS',
    'Seattle SuperSonics': 'SEA',   
    'Toronto Raptors': 'TOR',
    'Two or more teams': 'TOT',
    'Utah Jazz': 'UTA',
    'Washington Wizards': 'WAS'}
    
    for key in nba_teams:
        if tm_col == key:
            tm_abbrv = nba_teams[key]
            return(tm_abbrv)
        
salary_data_new["team"] = salary_data_new["team"].apply(lambda x: teamName(x))

# %%
salary_data_new.head()
# Out:
#   team  salary            Player position     season
# 0  MIN  25.200     Kevin Garnett       PF  2002-2003
# 1  POR  13.500  Damon Stoudamire       PG  2002-2003
# 2  SEA  13.080       Gary Payton       PG  2002-2003
# 3  SEA  12.375         Ray Allen       SG  2002-2003
# 4  NYK  12.375  Latrell Sprewell       SG  2002-2003

# %%
joined = season_data_new.merge(salary_data_new, on = ["Player", "season", "team"], how = "inner")
joined = joined.drop(columns = ["position"])
joined.head()
# Out:
#       season               Player Pos   Age team    PTS   AST   BLK    TOV  \
# 0  2002-2003        Zach Randolph  PF  21.0  POR  650.0  41.0  14.0   62.0
# 1  2002-2003  Vladimir Radmanovic  PF  22.0  SEA  724.0  97.0  22.0  100.0
# 2  2002-2003       Joel Przybilla   C  23.0  MIL   48.0  12.0  45.0   19.0
# 3  2002-2003     Vitaly Potapenko   C  27.0  SEA  104.0   4.0   8.0   25.0
# 4  2002-2003         Scot Pollard   C  27.0  SAC  103.0   6.0  15.0   15.0
#
#     STL  ...    ast_pg    blk_pg    tov_pg    stl_pg    reb_pg     min_pg  \
# 0  42.0  ...  0.532468  0.181818  0.805195  0.545455  4.454545  16.896104
# 1  64.0  ...  1.347222  0.305556  1.388889  0.888889  4.486111  26.527778
# 2  10.0  ...  0.375000  1.406250  0.593750  0.312500  4.531250  17.062500
# 3   9.0  ...  0.153846  0.307692  0.961538  0.346154  3.423077  15.500000
# 4  13.0  ...  0.260870  0.652174  0.652174  0.565217  4.608696  14.130435
#
#         FG%       FT%       3P%  salary
# 0  0.512621  0.757764  0.000000   1.096
# 1  0.410180  0.705882  0.354949   1.561
# 2  0.391304  0.500000       NaN   1.862
# 3  0.440860  0.758621       NaN   5.238
# 4  0.459770  0.605263       NaN   4.827
#
# [5 rows x 35 columns]

# %%
joined.shape
# Out:
# (4433, 35)

# %%
pd.unique(joined.columns)
#joined[joined.duplicated(["season", "Player"])]
# Out:
# array(['season', 'Player', 'Pos', 'Age', 'team', 'PTS', 'AST', 'BLK',
#        'TOV', 'STL', 'ORB', 'DRB', 'MP', 'G', 'GS', 'PF', 'FTA', 'FGA',
#        '3PA', '3P', 'FG', 'FT', 'PER', 'WS', 'ppg', 'ast_pg', 'blk_pg',
#        'tov_pg', 'stl_pg', 'reb_pg', 'min_pg', 'FG%', 'FT%', '3P%',
#        'salary'], dtype=object)

# %%
joined.to_csv("joined.csv")

# %%
joined.isna().any()
# Out:
# season    False
# Player    False
# Pos       False
# Age       False
# team      False
# PTS       False
# AST       False
# BLK       False
# TOV       False
# STL       False
# ORB       False
# DRB       False
# MP        False
# G         False
# GS        False
# PF        False
# FTA       False
# FGA       False
# 3PA       False
# 3P         True
# FG         True
# FT         True
# PER        True
# WS        False
# ppg       False
# ast_pg    False
# blk_pg    False
# tov_pg    False
# stl_pg    False
# reb_pg    False
# min_pg    False
# FG%        True
# FT%        True
# 3P%        True
# salary    False
# dtype: bool
