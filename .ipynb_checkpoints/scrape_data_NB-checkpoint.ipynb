# %%
import numpy as np 
import pandas as pd
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# Just for one season
url = "http://www.basketball-reference.com/leagues/NBA_2022_per_game.html"
response = requests.get(url) #make to many requests and you might get blocked lol
soup = BeautifulSoup(response.content, 'html.parser')

# %%
data = soup.find(id = "per_game_stats")
data_df = pd.concat(pd.read_html(str(data)))

# %%
# For multiple seasons
years = list(range(1999, 2025))

for year in years:
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
    data = requests.get(url)
    
    with open(f"years/{year}.html", "w+") as f:
        f.write(data.text)

# %%
all_season_data = []

for year in years:
    print(f'### {year} ###')
    with open(f'years/{year}.html') as f:
        page = f.read()

    soup = BeautifulSoup(page, 'html.parser')
    season_data = soup.find(id = "per_game_stats")
    season_data_df = pd.concat(pd.read_html(str(season_data)))


    all_season_data.append(season_data_df)
# Out:
# ### 1999 ###
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 10
#       8 soup = BeautifulSoup(page, 'html.parser')
#       9 season_data = soup.find(id = "div_per_game_stats")
# ---> 10 season_data = pd.read_html(str(season_data))[0]
#      11 season_data = pd.concat(season_data)
#      14 all_season_data.append(season_data)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
#    1222     encoding=encoding,
#    1223     decimal=decimal,
#    1224     converters=converters,
#    1225     na_values=na_values,
#    1226     keep_default_na=keep_default_na,
#    1227     displayed_only=displayed_only,
#    1228     extract_links=extract_links,
#    1229     dtype_backend=dtype_backend,
#    1230 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/html.py:1001, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     999 else:
#    1000     assert retained is not None  # for mypy
# -> 1001     raise retained
#    1003 ret = []
#    1004 for table in tables:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/html.py:981, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     978 p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     980 try:
# --> 981     tables = p.parse_tables()
#     982 except ValueError as caught:
#     983     # if `io` is an io-like object, check if it's seekable
#     984     # and try to rewind it before trying the next parser
#     985     if hasattr(io, "seekable") and io.seekable():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/html.py:257, in _HtmlFrameParser.parse_tables(self)
#     249 def parse_tables(self):
#     250     """
#     251     Parse and return all tables from the DOM.
#     252
#    (...)
#     255     list of parsed (header, body, footer) tuples from tables.
#     256     """
# --> 257     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     258     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/html.py:613, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     610 tables = doc.find_all(element_name, attrs=attrs)
#     612 if not tables:
# --> 613     raise ValueError("No tables found")
#     615 result = []
#     616 unique_tables = set()
#
# ValueError: No tables found

# %%
all_season_data[2]
# Out:
#       Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1  Precious Achiuwa  PF-C  24  TOT  74  18  21.9  3.2   6.3  ...  .616
# 1      1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...  .571
# 2      1  Precious Achiuwa    PF  24  NYK  49  18  24.2  3.2   6.1  ...  .643
# 3      2       Bam Adebayo     C  26  MIA  71  71  34.0  7.5  14.3  ...  .755
# 4      3      Ochai Agbaji    SG  23  TOT  78  28  21.0  2.3   5.6  ...  .661
# ..   ...               ...   ...  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 758  568    Thaddeus Young    PF  35  PHO  10   0   8.9  1.1   2.1  ...  .333
# 759  569        Trae Young    PG  25  ATL  54  54  36.0  8.0  18.7  ...  .855
# 760  570    Omer Yurtseven     C  25  UTA  48  12  11.4  2.1   3.8  ...  .679
# 761  571       Cody Zeller     C  31  NOP  43   0   7.4  0.6   1.4  ...  .605
# 762  572       Ivica Zubac     C  26  LAC  68  68  26.4  5.0   7.6  ...  .723
#
#      ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    2.6  4.0   6.6   1.3  0.6  0.9  1.1  1.9   7.6
# 1    2.0  3.4   5.4   1.8  0.6  0.5  1.2  1.6   7.7
# 2    2.9  4.3   7.2   1.1  0.6  1.1  1.1  2.1   7.6
# 3    2.2  8.1  10.4   3.9  1.1  0.9  2.3  2.2  19.3
# 4    0.9  1.8   2.8   1.1  0.6  0.6  0.8  1.5   5.8
# ..   ...  ...   ...   ...  ...  ...  ...  ...   ...
# 758  1.7  1.1   2.8   0.7  0.5  0.2  0.4  1.1   2.3
# 759  0.4  2.3   2.8  10.8  1.3  0.2  4.4  2.0  25.7
# 760  1.5  2.8   4.3   0.6  0.2  0.4  0.8  1.1   4.6
# 761  1.1  1.5   2.6   0.9  0.2  0.1  0.4  1.0   1.8
# 762  2.9  6.3   9.2   1.4  0.3  1.2  1.2  2.6  11.7
#
# [763 rows x 30 columns]
